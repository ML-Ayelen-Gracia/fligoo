# %%
try:
    import psycopg2
except:
    # !pip install psycopg2-binary
    import psycopg2
    
import pandas as pd

# PostgreSQL database connection parameters
db_params = {
    "host": "fligoodb",
    "database": "testfligoo",
    "user": "fligoo",
    "password": "fligoo",
}

# Connect to the PostgreSQL database
connection = psycopg2.connect(**db_params)

# Query to fetch all data from the testdata table
query = "SELECT * FROM testdata;"

# Use Pandas to read the data into a DataFrame
df = pd.read_sql_query(query, connection)

# Close the database connection
connection.close()

# Print the DataFrame
df
# Out:
# /tmp/ipykernel_106/3375321297.py:24: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query(query, connection)
#    flight_date flight_status          departure_airport  \
# 0   2023-10-25        active                     Mackay
# 1   2023-10-25        active            Manas (Bishkek)
# 2   2023-10-25        active    Abu Dhabi International
# 3   2023-10-25        active    Abu Dhabi International
# 4   2023-10-25        active    Abu Dhabi International
# ..         ...           ...                        ...
# 95  2023-10-25        active  Mactan-Cebu International
# 96  2023-10-25        active              Jackson Field
# 97  2023-10-25        active    Abu Dhabi International
# 98  2023-10-25        active                 Maningrida
# 99  2023-10-25        active             Darnley Island
#
#         departure_timezone                  arrival_airport  \
# 0     Australia - Brisbane                        Mount Isa
# 1           Asia - Bishkek                 Istanbul Airport
# 2             Asia - Dubai       Malé International Airport
# 3             Asia - Dubai       Malé International Airport
# 4             Asia - Dubai       Malé International Airport
# ..                     ...                              ...
# 95           Asia - Manila  Cagayan De Oro Domestic Airport
# 96  Pacific - Port_Moresby           Brisbane International
# 97            Asia - Dubai                             None
# 98      Australia - Darwin                           Darwin
# 99    Australia - Brisbane                      Horn Island
#
#       arrival_timezone arrival_terminal         airline_name  flight_number
# 0   Australia/Brisbane             None        Toll Aviation          132.0
# 1      Europe/Istanbul                I     Turkish Airlines          347.0
# 2      Indian/Maldives             MAIN       Etihad Airways          278.0
# 3      Indian/Maldives             MAIN               flynas         3278.0
# 4      Indian/Maldives             MAIN             Oman Air         5104.0
# ..                 ...              ...                  ...            ...
# 95         Asia/Manila                1     Cebu Pacific Air         6713.0
# 96  Australia/Brisbane                I          Air Niugini            5.0
# 97                None               T2           Air Arabia          525.0
# 98    Australia/Darwin                D                empty            NaN
# 99  Australia/Brisbane             None  Hinterland Aviation          622.0
#
# [100 rows x 9 columns]
